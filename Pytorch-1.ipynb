# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cu126

# %%
if torch.cuda.is_available():
  print("GPU is Available!")
  print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
  print("GPU is not Available!")
# Out:
# GPU is Available!
# Using GPU: Tesla T4

# %%
#using empty
torch.empty(2,3)
# Out:
# tensor([[-1.4876e+22,  4.3809e-41, -1.4858e+22],
#         [ 4.3809e-41, -1.4877e+22,  4.3809e-41]])

# %%
#using zeros
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
